# %% [markdown]
# # Geocode addresses
#
# Import the following libraries as usual.

# %%
import pandas as pd
import json

# %% [markdown]
# ## `censusgeocode`
#
# The Python library [`censusgeocode`](https://pypi.org/project/censusgeocode/) is a nice easy way to geocode data from the US Census. Make sure you look at that documentation.
#
# [The Census also has documentation](https://www.census.gov/programs-surveys/geography/technical-documentation/complete-technical-documentation/census-geocoder.html) you should read if you want to get into more geocoding.

# %%
import censusgeocode as cg

# %% [markdown]
# ## Geocode one address

# %% [markdown]
# Let's look at just one address. There's going to be a lot of data. (This is random.)

# %%
result = cg.address('1241 HOLMAN RD', city='Oakland', state='California')
result
# Out:
# [{'tigerLine': {'side': 'R', 'tigerLineId': '125002398'},
#   'geographies': {'2018 State Legislative Districts - Upper': [{'GEOID': '06009',
#      'CENTLAT': '+37.8692954',
#      'AREAWATER': 252962815,
#      'STATE': '06',
#      'BASENAME': '9',
#      'OID': '212904690192874',
#      'SLDU': '009',
#      'LSADC': 'LU',
#      'FUNCSTAT': 'N',
#      'INTPTLAT': '+37.8695634',
#      'NAME': 'State Senate District 9',
#      'OBJECTID': 1008,
#      'CENTLON': '-122.2639442',
#      'LSY': '2018',
#      'AREALAND': 512863741,
#      'INTPTLON': '-122.2625626',
#      'MTFCC': 'G5210',
#      'LDTYP': 'O'}],
#    'States': [{'STATENS': '01779778',
#      'GEOID': '06',
#      'CENTLAT': '+37.1547578',
#      'AREAWATER': 20291712025,
#      'STATE': '06',
#      'BASENAME': 'California',
#      'STUSAB': 'CA',
#      'OID': '2749018475066',
#      'LSADC': '00',
#      'FUNCSTAT': 'A',
#      'INTPTLAT': '+37.1551773',
#      'DIVISION': '9',
#      'NAME': 'California',
#      'REGION': '4',
#      'OBJECTID': 19,
#      'CENTLON': '-119.5277715',
#      'AREALAND': 403673617862,
#      'INTPTLON': '-119.5434183',
#      'MTFCC': 'G4000'}],
#    'County Subdivisions': [{'COUSUB': '92230',
#      'GEOID': '0600192230',
#      'CENTLAT': '+37.7725072',
#      'AREAWATER': 59659800,
#      'STATE': '06',
#      'BASENAME': 'Oakland',
#      'OID': '27690141295678',
#      'LSADC': '22',
#      'FUNCSTAT': 'S',
#      'INTPTLAT': '+37.7723881',
#      'NAME': 'Oakland CCD',
#      'OBJECTID': 30142,
#      'CENTLON': '-122.2266441',
#      'COUSUBCC': 'Z5',
#      'AREALAND': 152644687,
#      'INTPTLON': '-122.2271060',
#      'MTFCC': 'G4040',
#      'COUSUBNS': '01935228',
#      'COUNTY': '001'}],
#    'Incorporated Places': [{'NECTAPCI': 'N',
#      'GEOID': '0653000',
#      'CENTLAT': '+37.7695169',
#      'AREAWATER': 57160794,
#      'STATE': '06',
#      'BASENAME': 'Oakland',
#      'OID': '27890141296453',
#      'LSADC': '25',
#      'PLACE': '53000',
#      'FUNCSTAT': 'A',
#      'INTPTLAT': '+37.7698464',
#      'NAME': 'Oakland city',
#      'OBJECTID': 11948,
#      'PLACECC': 'C1',
#      'CENTLON': '-122.2244862',
#      'CBSAPCI': 'N',
#      'AREALAND': 144944705,
#      'INTPTLON': '-122.2256900',
#      'PLACENS': '02411292',
#      'MTFCC': 'G4110'}],
#    'Counties': [{'GEOID': '06001',
#      'CENTLAT': '+37.6505868',
#      'AREAWATER': 216909647,
#      'STATE': '06',
#      'BASENAME': 'Alameda',
#      'OID': '27590141293924',
#      'LSADC': '06',
#      'FUNCSTAT': 'A',
#      'INTPTLAT': '+37.6471385',
#      'NAME': 'Alameda County',
#      'OBJECTID': 2849,
#      'CENTLON': '-121.9178017',
#      'COUNTYCC': 'H1',
#      'COUNTYNS': '01675839',
#      'AREALAND': 1910010507,
#      'INTPTLON': '-121.9124880',
#      'MTFCC': 'G4020',
#      'COUNTY': '001'}],
#    '2018 State Legislative Districts - Lower': [{'GEOID': '06018',
#      'CENTLAT': '+37.7493496',
#      'SLDL': '018',
#      'AREAWATER': 98739489,
#      'STATE': '06',
#      'BASENAME': '18',
#      'OID': '213904690193333',
#      'LSADC': 'L3',
#      'FUNCSTAT': 'N',
#      'INTPTLAT': '+37.7418878',
#      'NAME': 'Assembly District 18',
#      'OBJECTID': 1587,
#      'CENTLON': '-122.2142920',
#      'LSY': '2018',
#      'AREALAND': 197325651,
#      'INTPTLON': '-122.2191890',
#      'MTFCC': 'G5220',
#      'LDTYP': 'O'}],
#    '116th Congressional Districts': [{'GEOID': '0613',
#      'CENTLAT': '+37.7784890',
#      'CDSESSN': '116',
#      'AREAWATER': 127113457,
#      'STATE': '06',
#      'BASENAME': '13',
#      'OID': '211904492478409',
#      'LSADC': 'C2',
#      'FUNCSTAT': 'N',
#      'INTPTLAT': '+37.7789619',
#      'NAME': 'Congressional District 13',
#      'OBJECTID': 26,
#      'CENTLON': '-122.2387620',
#      'AREALAND': 250658464,
#      'INTPTLON': '-122.2392482',
#      'CD116': '13',
#      'MTFCC': 'G5200'}],
#    '2020 Census Blocks': [{'SUFFIX': '',
#      'GEOID': '060014050003003',
#      'CENTLAT': '+37.8065162',
#      'BLOCK': '3003',
#      'AREAWATER': 0,
#      'STATE': '06',
#      'BASENAME': '3003',
#      'OID': '210701000686832',
#      'LSADC': 'BK',
#      'FUNCSTAT': 'S',
#      'INTPTLAT': '+37.8065162',
#      'NAME': 'Block 3003',
#      'OBJECTID': 1962398,
#      'TRACT': '405000',
#      'CENTLON': '-122.2288684',
#      'BLKGRP': '3',
#      'AREALAND': 16680,
#      'INTPTLON': '-122.2288684',
#      'MTFCC': 'G5040',
#      'LWBLKTYP': 'L',
#      'COUNTY': '001'}],
#    'Census Tracts': [{'GEOID': '06001405000',
#      'CENTLAT': '+37.8082767',
#      'AREAWATER': 0,
#      'STATE': '06',
#      'BASENAME': '4050',
#      'OID': '20790141324092',
#      'LSADC': 'CT',
#      'FUNCSTAT': 'S',
#      'INTPTLAT': '+37.8120851',
#      'NAME': 'Census Tract 4050',
#      'OBJECTID': 51714,
#      'TRACT': '405000',
#      'CENTLON': '-122.2276500',
#      'AREALAND': 800678,
#      'INTPTLON': '-122.2190899',
#      'MTFCC': 'G5020',
#      'COUNTY': '001'}]},
#   'coordinates': {'x': -122.23014397082626, 'y': 37.806448352151385},
#   'addressComponents': {'zip': '94610',
#    'streetName': 'HOLMAN',
#    'preType': '',
#    'city': 'OAKLAND',
#    'preDirection': '',
#    'suffixDirection': '',
#    'fromAddress': '1229',
#    'state': 'CA',
#    'suffixType': 'RD',
#    'toAddress': '1359',
#    'suffixQualifier': '',
#    'preQualifier': ''},
#   'matchedAddress': '1241 HOLMAN RD, OAKLAND, CA, 94610'}]

# %% [markdown]
# Check out how much the Census returns! It goes down to Census block and tract! You could do a very granular analysis using geocoded data like this.

# %% [markdown]
# The Census may return more than 1 address, so it's good to check how many results you have. Usually the first result is the most likely one.

# %%
len(result)
# Out:
# 1

# %%
result[0]['coordinates'] # returns lng, lat
# Out:
# {'x': -122.23014397082626, 'y': 37.806448352151385}

# %% [markdown]
# ## Batch geocode
#
# It's more efficient to upload a batch of addresses to Census and get a result back. So let's do that.
#
# ### Sample addresses
#
# The Census wants a CSV in the following format:
#
# ```
# 1,4600 Silver Hill Road,Washington,DC,20233
# ```
# How do I know this is what Census wants? [It's on their website.](https://geocoding.geo.census.gov/geocoder/locations/addressbatch?form) Click on the link that says `Download a sample CSV file here`.
#
# What does that format look like to you?
#
# ```
# index, street_address, city, state_abbreviation, zip_code
# ```
#
# ### Import addresses

# %%
addresses = pd.read_csv('exports/random_addresses_10.csv')
addresses
# Out:
#                 ADDRESS_CLEANED
# 0                500 E. 22ND ST
# 1                   900 36TH AV
# 2               47TH ST & DOVER
# 3                   850 PINE ST
# 4       5300 BLOCK OF JAMES AVE
# 5  INTERNATIONAL BLVD & 42ND AV
# 6              2000 CAMPBELL ST
# 7           611 OLD QUARRY LOOP
# 8             2045 EAST 15TH ST
# 9            MUNSON & E 15TH ST

# %%
# Fill in missing data
# This is from Oakland 311 data, so we know what the city and state will be.
# We can leave Zip blank for now.
addresses['City'] = 'Oakland'
addresses['State'] = 'CA'
addresses['Zip'] = ''
addresses
# Out:
#                 ADDRESS_CLEANED     City State Zip
# 0                500 E. 22ND ST  Oakland    CA
# 1                   900 36TH AV  Oakland    CA
# 2               47TH ST & DOVER  Oakland    CA
# 3                   850 PINE ST  Oakland    CA
# 4       5300 BLOCK OF JAMES AVE  Oakland    CA
# 5  INTERNATIONAL BLVD & 42ND AV  Oakland    CA
# 6              2000 CAMPBELL ST  Oakland    CA
# 7           611 OLD QUARRY LOOP  Oakland    CA
# 8             2045 EAST 15TH ST  Oakland    CA
# 9            MUNSON & E 15TH ST  Oakland    CA

# %%
# Export file to upload to Census
addresses.to_csv(
    'exports/addresses_10.csv', 
    index=True,  # Census is expecting an index as an ID! 
    header=False # This removes the top row with column names because Census doesn't want that
)

# %%
results = cg.addressbatch('exports/addresses_10.csv')

# %%
# Create a dataframe with the results
results_df = pd.DataFrame().from_records(results)
results_df
# Out:
#   id                                      address  match  matchtype  \
# 0  0                500 E. 22ND ST, Oakland, CA,    True      Exact
# 1  1                   900 36TH AV, Oakland, CA,    True      Exact
# 2  2               47TH ST & DOVER, Oakland, CA,   False       None
# 3  3                   850 PINE ST, Oakland, CA,    True      Exact
# 4  4       5300 BLOCK OF JAMES AVE, Oakland, CA,    True      Exact
# 5  5  INTERNATIONAL BLVD & 42ND AV, Oakland, CA,   False       None
# 6  6              2000 CAMPBELL ST, Oakland, CA,    True      Exact
# 7  7           611 OLD QUARRY LOOP, Oakland, CA,   False       None
# 8  8             2045 EAST 15TH ST, Oakland, CA,    True      Exact
# 9  9            MUNSON & E 15TH ST, Oakland, CA,    True  Non_Exact
#
#                                        parsed tigerlineid  side statefp  \
# 0             500 22ND ST, OAKLAND, CA, 94612   124996500     R      06
# 1            900 36TH AVE, OAKLAND, CA, 94601   125006474     R      06
# 2                                        None        None  None    None
# 3             850 PINE ST, OAKLAND, CA, 94607   124995322     R      06
# 4          5300 JAMES AVE, OAKLAND, CA, 94618   124999407     R      06
# 5                                        None        None  None    None
# 6        2000 CAMPBELL ST, OAKLAND, CA, 94607   606185175     R      06
# 7                                        None        None  None    None
# 8          2045 E 15TH ST, OAKLAND, CA, 94606   606190585     R      06
# 9  MUNSON WAY & E 15TH ST, OAKLAND, CA, 94606                        06
#
#   countyfp   tract block        lat         lon
# 0      001  402801  1011  37.811109 -122.269588
# 1      001  406100  2002  37.772940 -122.223884
# 2     None    None  None        NaN         NaN
# 3      001  401700  1006  37.809568 -122.302636
# 4      001  400300  4011  37.838561 -122.253707
# 5     None    None  None        NaN         NaN
# 6      001  401700  2007  37.816176 -122.291940
# 7     None    None  None        NaN         NaN
# 8      001  405901  1005  37.786372 -122.238749
# 9      001  405901  1010  37.784883 -122.236251

# %%
results_df_notnull = results_df.dropna(subset=['lat'])
results_df_notnull
# Out:
#   id                                 address  match  matchtype  \
# 0  0           500 E. 22ND ST, Oakland, CA,    True      Exact
# 1  1              900 36TH AV, Oakland, CA,    True      Exact
# 3  3              850 PINE ST, Oakland, CA,    True      Exact
# 4  4  5300 BLOCK OF JAMES AVE, Oakland, CA,    True      Exact
# 6  6         2000 CAMPBELL ST, Oakland, CA,    True      Exact
# 8  8        2045 EAST 15TH ST, Oakland, CA,    True      Exact
# 9  9       MUNSON & E 15TH ST, Oakland, CA,    True  Non_Exact
#
#                                        parsed tigerlineid side statefp  \
# 0             500 22ND ST, OAKLAND, CA, 94612   124996500    R      06
# 1            900 36TH AVE, OAKLAND, CA, 94601   125006474    R      06
# 3             850 PINE ST, OAKLAND, CA, 94607   124995322    R      06
# 4          5300 JAMES AVE, OAKLAND, CA, 94618   124999407    R      06
# 6        2000 CAMPBELL ST, OAKLAND, CA, 94607   606185175    R      06
# 8          2045 E 15TH ST, OAKLAND, CA, 94606   606190585    R      06
# 9  MUNSON WAY & E 15TH ST, OAKLAND, CA, 94606                       06
#
#   countyfp   tract block        lat         lon
# 0      001  402801  1011  37.811109 -122.269588
# 1      001  406100  2002  37.772940 -122.223884
# 3      001  401700  1006  37.809568 -122.302636
# 4      001  400300  4011  37.838561 -122.253707
# 6      001  401700  2007  37.816176 -122.291940
# 8      001  405901  1005  37.786372 -122.238749
# 9      001  405901  1010  37.784883 -122.236251

# %% [markdown]
# What are you noticing here?

# %%
# Export your data
results_df_notnull.to_csv('exports/census_results.csv', index=False)
