# %% [markdown]
# # Get a list of addresses to geocode

# %%
import pandas as pd

# %%
oakland311 = pd.read_csv('../oakland_311_cleaned.csv')
oakland311.tail()
# Out:
#         REQUESTID         DATETIMEINIT       SOURCE  \
# 935469    1114706  2021-05-19 16:27:17  SeeClickFix
# 935470    1124225  2021-06-24 12:07:46  SeeClickFix
# 935471    1119508  2021-06-07 15:25:51  SeeClickFix
# 935472    1114657  2021-05-19 14:35:57    Voicemail
# 935473    1108146  2021-04-26 14:37:02        Phone
#
#                                        DESCRIPTION REQCATEGORY  \
# 935469                 Parking - Abandoned Vehicle      POLICE
# 935470  Illegal Dumping - debris, appliances, etc.     ILLDUMP
# 935471                 Parking - Abandoned Vehicle      POLICE
# 935472             Recycling - Repair/Replace Cart   RECYCLING
# 935473  Illegal Dumping - debris, appliances, etc.     ILLDUMP
#
#                                        REQADDRESS  STATUS REFERREDTO  \
# 935469  (37.773695001577835, -122.17537597640717)  CLOSED        NaN
# 935470  (37.849167834332334, -122.28460742401488)  CLOSED        NaN
# 935471  (37.802163003247536, -122.23499896883865)  CANCEL        NaN
# 935472   (37.81240377066922, -122.27655475245274)  CLOSED        NaN
# 935473   (37.84761984869444, -122.25216142316818)  CLOSED        NaN
#
#              DATETIMECLOSED          SRX          SRY COUNCILDISTRICT BEAT  \
# 935469  2021-08-02 13:20:17  6077464.481  2108516.009            CCD6  29X
# 935470  2021-06-25 17:38:07  6046423.116  2136576.035            CCD1  10X
# 935471                  NaN  6060426.881  2119194.029            CCD2  17Y
# 935472  2021-05-21 15:42:05  6048493.657  2123147.497            CCD3  05X
# 935473  2021-04-30 15:35:32  6055779.117  2135835.460            CCD1  12Y
#
#             PROBADDRESS     City State      ELAPSED_TIME
# 935469   6618 LAIRD AVE  Oakland    CA  74 days 20:53:00
# 935470    6628 HELEN CT  Oakland    CA   1 days 05:30:21
# 935471   3219 ELLIOT ST  Oakland    CA               NaN
# 935472     2131 WEST ST  Oakland    CA   2 days 01:06:08
# 935473  5951 COLLEGE AV  Oakland    CA   4 days 00:58:30

# %% [markdown]
# ## What are you noticing about geographic point data and street addresses?
#
# - `REQADDRESS` has geographic coordinates
# - `PROBADDRESS` has street address

# %% [markdown]
# I like to use `df.sample(n)` to get random rows of data. Let's look at the addresses we have to clean!

# %%
oakland311.sample(20)[['PROBADDRESS']]
# Out:
#                         PROBADDRESS
# 309077               5620 HARMON AV
# 12675             646 BOULEVARD WAY
# 784778         14TH AVE & E 12TH ST
# 222449              FIRE STATION 21
# 148245              3318 MAPLE AVE.
# 747491               DIMOND LIBRARY
# 783080    45TH AVE & SAN LEANDRO ST
# 587490                    9332 E ST
# 377562  JACK LONDON AQUATICS CENTER
# 559989        MCDONELL AV & FIRE RD
# 43686                 3448 DAVIS ST
# 32211    Courtland Ave & Tyrrell St
# 749073           1201�1299 96TH AVE
# 686571                  463 41ST ST
# 380630                   230 BAY PL
# 594958                2057 23RD AVE
# 687308              345 PERSHING DR
# 96240                   848 60TH ST
# 133766                3101 E 7TH ST
# 16728             9333 RAILROAD AVE

# %% [markdown]
# We learned some string normalizing ideas in [Lecture 1031](../lecture1031/lecture1031_pt3_cleaning.ipynb). String normalizing can help you spot duplicate data. Why would we want to do this?
#
# Let's take the address `2505 Hearst Ave, Berkeley, CA 94709`. It could be written in the data as:
# - 2505 HEARST AVE
# - 2505 Hearst Ave
#
# In this case, if we capitalize everything, pandas will immediately identify the 2 addresses as duplicates. So then when you request the geographic points from a geocoder, you won't have to submit both `2505 HEARST AVE` AND `2505 Hearst Ave`.
#
#
# ## Clean up the `PROBADDRESS` field
#
# Let's create a new column called `ADDRESS_CLEANED`.

# %%
# Uppercase the new column:
oakland311['ADDRESS_CLEANED'] = oakland311['PROBADDRESS'].str.upper()

# Create a new column and replace 2+ whitespaces with 1 whitespace:
oakland311['ADDRESS_CLEANED'] = oakland311['ADDRESS_CLEANED'].str.replace(r'[ ]+', ' ', regex=True)

# Remove leading and trailing whitespaces from the new column:
oakland311['ADDRESS_CLEANED'] = oakland311['ADDRESS_CLEANED'].str.strip()

# %% [markdown]
# There are other techniques we could use, like converting all `STREET` into `ST` and `ROAD` into `RD` and so forth. This is a simple lecture, so we're not going to do that.

# %%
addresses_to_geocode = oakland311[
    ( oakland311['REQADDRESS'].isnull() ) & 
    ( oakland311['PROBADDRESS'].notnull() )
].reset_index(drop=True)
addresses_to_geocode
# Out:
#        REQUESTID         DATETIMEINIT     SOURCE  \
# 0        1119698  2021-06-08 09:06:47      Phone
# 1        1112327  2021-05-11 11:50:04      Phone
# 2        1113081  2021-05-13 13:46:02      Phone
# 3        1123941  2021-06-23 11:17:40  Voicemail
# 4        1120645  2021-06-11 10:28:54      Phone
# ...          ...                  ...        ...
# 17069    1120609  2021-06-11 08:53:57      Phone
# 17070    1113573  2021-05-15 17:29:28      Phone
# 17071    1120590  2021-06-11 08:14:03      Phone
# 17072    1120594  2021-06-11 08:22:46      Phone
# 17073    1111146  2021-05-06 12:23:23      Phone
#
#                                       DESCRIPTION   REQCATEGORY REQADDRESS  \
# 0            Illegal Dumping � mattress/boxspring       ILLDUMP        NaN
# 1                     Parking - Meter Maintenance  METER_REPAIR        NaN
# 2                  Streets - Street Deterioration      STREETSW        NaN
# 3               Recycling Hotline - Miscellaneous     RECYCLING        NaN
# 4      Illegal Dumping - debris, appliances, etc.       ILLDUMP        NaN
# ...                                           ...           ...        ...
# 17069                           Sewers - Blockage        SEWERS        NaN
# 17070                   City Bldg - Other/Complex     BLDGMAINT        NaN
# 17071  Illegal Dumping - debris, appliances, etc.       ILLDUMP        NaN
# 17072                 Parking - Abandoned Vehicle        POLICE        NaN
# 17073                          Graffiti in a Park     BLDGMAINT        NaN
#
#        STATUS    REFERREDTO       DATETIMECLOSED  SRX  SRY COUNCILDISTRICT  \
# 0      CLOSED           NaN  2021-06-08 20:16:06  NaN  NaN             NaN
# 1      CLOSED           NaN  2021-05-13 07:30:38  NaN  NaN             NaN
# 2        OPEN           NaN                  NaN  NaN  NaN             NaN
# 3      CLOSED           NaN  2021-06-23 11:17:55  NaN  NaN             NaN
# 4      CLOSED           NaN  2021-06-14 19:57:27  NaN  NaN             NaN
# ...       ...           ...                  ...  ...  ...             ...
# 17069  CLOSED           NaN  2021-06-29 07:09:33  NaN  NaN             NaN
# 17070  CLOSED  GETWOOD, ROY  2021-06-02 13:43:29  NaN  NaN             NaN
# 17071  CLOSED           NaN  2021-06-21 16:03:04  NaN  NaN             NaN
# 17072  CANCEL           NaN                  NaN  NaN  NaN             NaN
# 17073  CLOSED           NaN  2021-05-17 14:58:57  NaN  NaN             NaN
#
#       BEAT                                        PROBADDRESS     City State  \
# 0      NaN                                   99TH AVE & BIRCH  Oakland    CA
# 1      NaN                           GRAND AV & SUNNYSLOPE AV  Oakland    CA
# 2      NaN                                      94TH & LAWLER  Oakland    CA
# 3      NaN                                                 ZZ  Oakland    CA
# 4      NaN                            94TH AVE & BANCROFT AVE  Oakland    CA
# ...    ...                                                ...      ...   ...
# 17069  NaN                                  7044 NORFOLK ROAD  Oakland    CA
# 17070  NaN  Cross streets are skyline and juaqiem miller m...  Oakland    CA
# 17071  NaN                                          1310 76TH  Oakland    CA
# 17072  21X                                  2343 EAST 24TH ST  Oakland    CA
# 17073  NaN            FOOTHILL MEADOWS (CESAR E. CHAVEZ) PARK  Oakland    CA
#
#            ELAPSED_TIME                                    ADDRESS_CLEANED
# 0       0 days 11:09:19                                   99TH AVE & BIRCH
# 1       1 days 19:40:34                           GRAND AV & SUNNYSLOPE AV
# 2                   NaN                                      94TH & LAWLER
# 3       0 days 00:00:15                                                 ZZ
# 4       3 days 09:28:33                            94TH AVE & BANCROFT AVE
# ...                 ...                                                ...
# 17069  17 days 22:15:36                                  7044 NORFOLK ROAD
# 17070  17 days 20:14:01  CROSS STREETS ARE SKYLINE AND JUAQIEM MILLER M...
# 17071  10 days 07:49:01                                          1310 76TH
# 17072               NaN                                  2343 EAST 24TH ST
# 17073  11 days 02:35:34            FOOTHILL MEADOWS (CESAR E. CHAVEZ) PARK
#
# [17074 rows x 18 columns]

# %%
num_addresses_og = addresses_to_geocode['PROBADDRESS'].nunique()
num_addresses_cleaned = addresses_to_geocode['ADDRESS_CLEANED'].nunique()
reduced = num_addresses_og - num_addresses_cleaned

# %%
print(f"Reduced total addresses to geocode from { num_addresses_og } addresses to { num_addresses_cleaned } addresses. That's { reduced } addresses we deduped.")
# Out:
# Reduced total addresses to geocode from 8298 addresses to 8141 addresses. That's 157 addresses we deduped.

# %% [markdown]
# ## Exports
#
# ### Export cleaned up dataset with new column
#
# Export a version of your original dataset with the cleaned up column name so we have a column to match on later.

# %%
# create an exports folder
# !mkdir -p exports

# %%
addresses_to_geocode.to_csv('exports/oakland311_cleaned.csv', index=False)

# %% [markdown]
# ### Export addresses to geocode
#
# The code below is commented out because I do not want to geocode thousands of addresses for this lecture!

# %%
# addresses_to_geocode[['ADDRESS_CLEANED']].drop_duplicates().to_csv('exports/addresses_to_geocode.csv', index=False)

# %% [markdown]
# For the purposes of this lecture, I only want to geocode 10 addresses. Otherwise it's going to take forever. And there will likely be failures!

# %%
deduped = addresses_to_geocode[['ADDRESS_CLEANED']].drop_duplicates()
addresses_sample = deduped.sample(10).reset_index(drop=True)
addresses_sample[['ADDRESS_CLEANED']]
# Out:
#                 ADDRESS_CLEANED
# 0                500 E. 22ND ST
# 1                   900 36TH AV
# 2               47TH ST & DOVER
# 3                   850 PINE ST
# 4       5300 BLOCK OF JAMES AVE
# 5  INTERNATIONAL BLVD & 42ND AV
# 6              2000 CAMPBELL ST
# 7           611 OLD QUARRY LOOP
# 8             2045 EAST 15TH ST
# 9            MUNSON & E 15TH ST

# %%
# export
addresses_sample[['ADDRESS_CLEANED']].to_csv('exports/random_addresses_10.csv', index=False)
