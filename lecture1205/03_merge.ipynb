# %% [markdown]
# # Merge geocode results back to dataset

# %%
import pandas as pd
# I showed geopandas during the 11/28 study hall
import geopandas as gpd

# %% [markdown]
# ## Import Oakland 311 data with cleaned up street address

# %%
oakland311 = pd.read_csv('exports/oakland311_cleaned.csv')
oakland311.tail()
# Out:
#        REQUESTID         DATETIMEINIT SOURCE  \
# 17069    1120609  2021-06-11 08:53:57  Phone
# 17070    1113573  2021-05-15 17:29:28  Phone
# 17071    1120590  2021-06-11 08:14:03  Phone
# 17072    1120594  2021-06-11 08:22:46  Phone
# 17073    1111146  2021-05-06 12:23:23  Phone
#
#                                       DESCRIPTION REQCATEGORY  REQADDRESS  \
# 17069                           Sewers - Blockage      SEWERS         NaN
# 17070                   City Bldg - Other/Complex   BLDGMAINT         NaN
# 17071  Illegal Dumping - debris, appliances, etc.     ILLDUMP         NaN
# 17072                 Parking - Abandoned Vehicle      POLICE         NaN
# 17073                          Graffiti in a Park   BLDGMAINT         NaN
#
#        STATUS    REFERREDTO       DATETIMECLOSED  SRX  SRY COUNCILDISTRICT  \
# 17069  CLOSED           NaN  2021-06-29 07:09:33  NaN  NaN             NaN
# 17070  CLOSED  GETWOOD, ROY  2021-06-02 13:43:29  NaN  NaN             NaN
# 17071  CLOSED           NaN  2021-06-21 16:03:04  NaN  NaN             NaN
# 17072  CANCEL           NaN                  NaN  NaN  NaN             NaN
# 17073  CLOSED           NaN  2021-05-17 14:58:57  NaN  NaN             NaN
#
#       BEAT                                        PROBADDRESS     City State  \
# 17069  NaN                                  7044 NORFOLK ROAD  Oakland    CA
# 17070  NaN  Cross streets are skyline and juaqiem miller m...  Oakland    CA
# 17071  NaN                                          1310 76TH  Oakland    CA
# 17072  21X                                  2343 EAST 24TH ST  Oakland    CA
# 17073  NaN            FOOTHILL MEADOWS (CESAR E. CHAVEZ) PARK  Oakland    CA
#
#            ELAPSED_TIME                                    ADDRESS_CLEANED
# 17069  17 days 22:15:36                                  7044 NORFOLK ROAD
# 17070  17 days 20:14:01  CROSS STREETS ARE SKYLINE AND JUAQIEM MILLER M...
# 17071  10 days 07:49:01                                          1310 76TH
# 17072               NaN                                  2343 EAST 24TH ST
# 17073  11 days 02:35:34            FOOTHILL MEADOWS (CESAR E. CHAVEZ) PARK

# %% [markdown]
# ## Import geocode results data

# %%
geo_data_df = pd.read_csv(
    'exports/census_results.csv', 
    dtype={
        'tigerlineid': str,
        'statefp': str,
        'countyfp': str,
        'tract': str,
        'block': str
    }
)
geo_data_df
# Out:
#    id                                 address  match  matchtype  \
# 0   0           500 E. 22ND ST, Oakland, CA,    True      Exact
# 1   1              900 36TH AV, Oakland, CA,    True      Exact
# 2   3              850 PINE ST, Oakland, CA,    True      Exact
# 3   4  5300 BLOCK OF JAMES AVE, Oakland, CA,    True      Exact
# 4   6         2000 CAMPBELL ST, Oakland, CA,    True      Exact
# 5   8        2045 EAST 15TH ST, Oakland, CA,    True      Exact
# 6   9       MUNSON & E 15TH ST, Oakland, CA,    True  Non_Exact
#
#                                        parsed tigerlineid side statefp  \
# 0             500 22ND ST, OAKLAND, CA, 94612   124996500    R      06
# 1            900 36TH AVE, OAKLAND, CA, 94601   125006474    R      06
# 2             850 PINE ST, OAKLAND, CA, 94607   124995322    R      06
# 3          5300 JAMES AVE, OAKLAND, CA, 94618   124999407    R      06
# 4        2000 CAMPBELL ST, OAKLAND, CA, 94607   606185175    R      06
# 5          2045 E 15TH ST, OAKLAND, CA, 94606   606190585    R      06
# 6  MUNSON WAY & E 15TH ST, OAKLAND, CA, 94606         NaN  NaN      06
#
#   countyfp   tract block        lat         lon
# 0      001  402801  1011  37.811109 -122.269588
# 1      001  406100  2002  37.772940 -122.223884
# 2      001  401700  1006  37.809568 -122.302636
# 3      001  400300  4011  37.838561 -122.253707
# 4      001  401700  2007  37.816176 -122.291940
# 5      001  405901  1005  37.786372 -122.238749
# 6      001  405901  1010  37.784883 -122.236251

# %%
geo_data_gdf = gpd.GeoDataFrame(
    geo_data_df, 
    geometry=gpd.points_from_xy(
        geo_data_df['lon'], 
        geo_data_df['lat']
    )
)
geo_data_gdf
# Out:
#    id                                 address  match  matchtype  \
# 0   0           500 E. 22ND ST, Oakland, CA,    True      Exact
# 1   1              900 36TH AV, Oakland, CA,    True      Exact
# 2   3              850 PINE ST, Oakland, CA,    True      Exact
# 3   4  5300 BLOCK OF JAMES AVE, Oakland, CA,    True      Exact
# 4   6         2000 CAMPBELL ST, Oakland, CA,    True      Exact
# 5   8        2045 EAST 15TH ST, Oakland, CA,    True      Exact
# 6   9       MUNSON & E 15TH ST, Oakland, CA,    True  Non_Exact
#
#                                        parsed tigerlineid side statefp  \
# 0             500 22ND ST, OAKLAND, CA, 94612   124996500    R      06
# 1            900 36TH AVE, OAKLAND, CA, 94601   125006474    R      06
# 2             850 PINE ST, OAKLAND, CA, 94607   124995322    R      06
# 3          5300 JAMES AVE, OAKLAND, CA, 94618   124999407    R      06
# 4        2000 CAMPBELL ST, OAKLAND, CA, 94607   606185175    R      06
# 5          2045 E 15TH ST, OAKLAND, CA, 94606   606190585    R      06
# 6  MUNSON WAY & E 15TH ST, OAKLAND, CA, 94606         NaN  NaN      06
#
#   countyfp   tract block        lat         lon                     geometry
# 0      001  402801  1011  37.811109 -122.269588  POINT (-122.26959 37.81111)
# 1      001  406100  2002  37.772940 -122.223884  POINT (-122.22388 37.77294)
# 2      001  401700  1006  37.809568 -122.302636  POINT (-122.30264 37.80957)
# 3      001  400300  4011  37.838561 -122.253707  POINT (-122.25371 37.83856)
# 4      001  401700  2007  37.816176 -122.291940  POINT (-122.29194 37.81618)
# 5      001  405901  1005  37.786372 -122.238749  POINT (-122.23875 37.78637)
# 6      001  405901  1010  37.784883 -122.236251  POINT (-122.23625 37.78488)

# %% [markdown]
# ## How will we merge these two datasets?

# %%
geo_data_gdf.iloc[0]
# Out:
# id                                                         0
# address                        500 E. 22ND ST, Oakland, CA,
# match                                                   True
# matchtype                                              Exact
# parsed                       500 22ND ST, OAKLAND, CA, 94612
# tigerlineid                                        124996500
# side                                                       R
# statefp                                                   06
# countyfp                                                 001
# tract                                                 402801
# block                                                   1011
# lat                                                37.811109
# lon                                              -122.269588
# geometry       POINT (-122.26958841199996 37.81110892100003)
# Name: 0, dtype: object

# %%
geo_data_gdf['ADDRESS_CLEANED'] = geo_data_gdf['address'].str.replace(
    ', Oakland, CA, ',
    '',
    regex=False
)
geo_data_gdf
# Out:
#    id                                 address  match  matchtype  \
# 0   0           500 E. 22ND ST, Oakland, CA,    True      Exact
# 1   1              900 36TH AV, Oakland, CA,    True      Exact
# 2   3              850 PINE ST, Oakland, CA,    True      Exact
# 3   4  5300 BLOCK OF JAMES AVE, Oakland, CA,    True      Exact
# 4   6         2000 CAMPBELL ST, Oakland, CA,    True      Exact
# 5   8        2045 EAST 15TH ST, Oakland, CA,    True      Exact
# 6   9       MUNSON & E 15TH ST, Oakland, CA,    True  Non_Exact
#
#                                        parsed tigerlineid side statefp  \
# 0             500 22ND ST, OAKLAND, CA, 94612   124996500    R      06
# 1            900 36TH AVE, OAKLAND, CA, 94601   125006474    R      06
# 2             850 PINE ST, OAKLAND, CA, 94607   124995322    R      06
# 3          5300 JAMES AVE, OAKLAND, CA, 94618   124999407    R      06
# 4        2000 CAMPBELL ST, OAKLAND, CA, 94607   606185175    R      06
# 5          2045 E 15TH ST, OAKLAND, CA, 94606   606190585    R      06
# 6  MUNSON WAY & E 15TH ST, OAKLAND, CA, 94606         NaN  NaN      06
#
#   countyfp   tract block        lat         lon                     geometry  \
# 0      001  402801  1011  37.811109 -122.269588  POINT (-122.26959 37.81111)
# 1      001  406100  2002  37.772940 -122.223884  POINT (-122.22388 37.77294)
# 2      001  401700  1006  37.809568 -122.302636  POINT (-122.30264 37.80957)
# 3      001  400300  4011  37.838561 -122.253707  POINT (-122.25371 37.83856)
# 4      001  401700  2007  37.816176 -122.291940  POINT (-122.29194 37.81618)
# 5      001  405901  1005  37.786372 -122.238749  POINT (-122.23875 37.78637)
# 6      001  405901  1010  37.784883 -122.236251  POINT (-122.23625 37.78488)
#
#            ADDRESS_CLEANED
# 0           500 E. 22ND ST
# 1              900 36TH AV
# 2              850 PINE ST
# 3  5300 BLOCK OF JAMES AVE
# 4         2000 CAMPBELL ST
# 5        2045 EAST 15TH ST
# 6       MUNSON & E 15TH ST

# %% [markdown]
# ## Merge on key
#
# I'm going to do an INNER join because we only geocoded a handful of addresses and I don't want to show the entire dataframe for lecture. However, in a real-life newsroom assignment, you would have to deal with the missing geocoded addresses in some other kind of way.

# %%
merged = pd.merge(oakland311, geo_data_gdf, on='ADDRESS_CLEANED', how='inner')
merged
# Out:
#    REQUESTID         DATETIMEINIT          SOURCE  \
# 0    1212074  2022-06-02 13:39:35  Phone or Email
# 1     424988  2012-09-11 11:12:54  Phone or Email
# 2     445956  2013-02-07 12:53:04  Phone or Email
# 3     573447  2015-03-26 09:42:57           Email
# 4    1047980  2020-09-17 15:04:11  Phone or Email
# 5    1065839  2020-11-16 13:13:56           Phone
# 6    1092129  2021-02-25 11:19:02       Voicemail
#
#                                   DESCRIPTION REQCATEGORY  REQADDRESS  \
# 0                 Parking - Abandoned Vehicle      POLICE         NaN
# 1        Illegal Dumping � mattress/boxspring     ILLDUMP         NaN
# 2  Illegal Dumping - debris, appliances, etc.     ILLDUMP         NaN
# 3     Recycling - Missed Pickup - Whole Block   RECYCLING         NaN
# 4        Illegal Dumping � mattress/boxspring     ILLDUMP         NaN
# 5               Streets - Potholes/Depression    STREETSW         NaN
# 6                    Recycling Service Issues   RECYCLING         NaN
#
#                 STATUS REFERREDTO       DATETIMECLOSED  SRX  ...  \
# 0  WAITING ON CUSTOMER        NaN                  NaN  NaN  ...
# 1               CLOSED        NaN  2012-09-13 16:41:52  NaN  ...
# 2               CLOSED        NaN  2013-04-10 17:00:54  NaN  ...
# 3               CLOSED        NaN  2015-03-26 17:06:21  NaN  ...
# 4               CLOSED        NaN  2020-09-21 15:58:58  NaN  ...
# 5                 OPEN        NaN                  NaN  NaN  ...
# 6               CLOSED        NaN  2021-02-26 13:41:56  NaN  ...
#
#                                        parsed tigerlineid side statefp  \
# 0            900 36TH AVE, OAKLAND, CA, 94601   125006474    R      06
# 1  MUNSON WAY & E 15TH ST, OAKLAND, CA, 94606         NaN  NaN      06
# 2             850 PINE ST, OAKLAND, CA, 94607   124995322    R      06
# 3          5300 JAMES AVE, OAKLAND, CA, 94618   124999407    R      06
# 4        2000 CAMPBELL ST, OAKLAND, CA, 94607   606185175    R      06
# 5          2045 E 15TH ST, OAKLAND, CA, 94606   606190585    R      06
# 6             500 22ND ST, OAKLAND, CA, 94612   124996500    R      06
#
#   countyfp   tract block        lat         lon                     geometry
# 0      001  406100  2002  37.772940 -122.223884  POINT (-122.22388 37.77294)
# 1      001  405901  1010  37.784883 -122.236251  POINT (-122.23625 37.78488)
# 2      001  401700  1006  37.809568 -122.302636  POINT (-122.30264 37.80957)
# 3      001  400300  4011  37.838561 -122.253707  POINT (-122.25371 37.83856)
# 4      001  401700  2007  37.816176 -122.291940  POINT (-122.29194 37.81618)
# 5      001  405901  1005  37.786372 -122.238749  POINT (-122.23875 37.78637)
# 6      001  402801  1011  37.811109 -122.269588  POINT (-122.26959 37.81111)
#
# [7 rows x 32 columns]

# %% [markdown]
# ## Export your clean data!

# %%
merged.to_csv('exports/oakland311_geo.csv', index=False)
