# %% [markdown]
# # Lecture 1031: Cleaning up and 'normalizing' string columns

# %%
import pandas as pd
import re # this is python's regex library

# %% [markdown]
# ## Import data
#
# Note that I'm importing `export.csv`, which I saved from Excel. I'm doing this solely to show you how to clean up strings. However, if you import the Excel file, the `AMOUNT` is clearly typed as a float.

# %%
# data_from_excel = pd.read_csv('newsom_contribs.csv',
#     dtype={
#         'ID NUMBER' : object
#     },
#     parse_dates=['TRANSACTION DATE', 'FILED DATE']
# )
# data_from_excel

# %%
data = pd.read_csv('export.csv',
    dtype={
        'ID NUMBER' : object
    },
    parse_dates=['TRANSACTION DATE', 'FILED DATE']
)
data
# Out:
#                            NAME OF CONTRIBUTOR PAYMENT TYPE           CITY  \
# 0      CALIFORNIA CHIROPRACTIC ASSOCIATION PAC     MONETARY     SACRAMENTO
# 1                               MARINA BILAVER     MONETARY      HOLLYWOOD
# 2                              CAMERON BLOOMER     MONETARY       NEW YORK
# 3                              ALISON FLEMMING     MONETARY       LARKSPUR
# 4                               WILLIAM FOWKES     MONETARY       LA HONDA
# ...                                        ...          ...            ...
# 23381                     1-800 CONTACTS, INC.     MONETARY         DRAPER
# 23382                       T-MOBILE USA, INC.     MONETARY       BELLEVUE
# 23383      GOOGLE, LLC AND AFFILIATED ENTITIES     MONETARY  MOUNTAIN VIEW
# 23384                     AIRLINES FOR AMERICA     MONETARY     WASHINGTON
# 23385                          JOSEPH E. GORST     MONETARY      SAN DIEGO
#
#       STATE    ZIP ID NUMBER            EMPLOYER          OCCUPATION  \
# 0        CA  95814    742986                 NaN                 NaN
# 1        CA  90028       NaN                 NaN        NOT EMPLOYED
# 2        NY  10010       NaN     BLOOMER BIOTECH  INVESTMENT ADVISOR
# 3        CA  94904       NaN  COOPER & MCCLOSKEY    INSURANCE BROKER
# 4        CA  94020       NaN                 NaN        NOT EMPLOYED
# ...     ...    ...       ...                 ...                 ...
# 23381    UT  84020       NaN                 NaN                 NaN
# 23382    WA  98006       NaN                 NaN                 NaN
# 23383    CA  94043       NaN                 NaN                 NaN
# 23384    DC  20004       NaN                 NaN                 NaN
# 23385    CA  92103       NaN                 NaN             RETIRED
#
#              AMOUNT TRANSACTION DATE FILED DATE  TRANSACTION NUMBER
# 0      ($15,000.00)       2021-09-07 2022-05-20   2625145 - EXP2027
# 1           $10.00        2021-07-01 2022-05-20  2625145 - IDT41416
# 2          $100.00        2021-07-01 2022-05-20  2625145 - IDT41417
# 3          $150.00        2021-07-01 2022-05-20  2625145 - IDT41424
# 4           $25.00        2021-07-01 2022-05-20  2625145 - IDT41425
# ...             ...              ...        ...                 ...
# 23381   $10,000.00        2021-12-22 2022-06-06   2644331 - INC3631
# 23382    $5,000.00        2021-12-22 2022-06-06   2644331 - INC3632
# 23383   $32,400.00        2021-12-27 2022-06-06   2644331 - INC3634
# 23384   $10,000.00        2021-12-28 2022-06-06   2644331 - INC3642
# 23385      $500.00        2021-12-31 2022-06-06   2644331 - INC3650
#
# [23386 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23386 entries, 0 to 23385
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NAME OF CONTRIBUTOR  23386 non-null  object
#  1   PAYMENT TYPE         23386 non-null  object
#  2   CITY                 23383 non-null  object
#  3   STATE                23368 non-null  object
#  4   ZIP                  23376 non-null  object
#  5   ID NUMBER            149 non-null    object
#  6   EMPLOYER             10234 non-null  object
#  7   OCCUPATION           23017 non-null  object
#  8   AMOUNT               23386 non-null  object
#  9   TRANSACTION DATE     23386 non-null  datetime64[ns]
#  10  FILED DATE           23386 non-null  datetime64[ns]
#  11  TRANSACTION NUMBER   23386 non-null  object
# dtypes: datetime64[ns](2), object(10)
# memory usage: 2.1+ MB

# %% [markdown]
# POLL: What are you noticing about the `AMOUNT` column? [https://pollev.com/soooh](https://pollev.com/soooh)

# %% [markdown]
# ## Clean up `AMOUNT` column

# %%
data.head()
# Out:
#                        NAME OF CONTRIBUTOR PAYMENT TYPE        CITY STATE  \
# 0  CALIFORNIA CHIROPRACTIC ASSOCIATION PAC     MONETARY  SACRAMENTO    CA
# 1                           MARINA BILAVER     MONETARY   HOLLYWOOD    CA
# 2                          CAMERON BLOOMER     MONETARY    NEW YORK    NY
# 3                          ALISON FLEMMING     MONETARY    LARKSPUR    CA
# 4                           WILLIAM FOWKES     MONETARY    LA HONDA    CA
#
#      ZIP ID NUMBER            EMPLOYER          OCCUPATION        AMOUNT  \
# 0  95814    742986                 NaN                 NaN  ($15,000.00)
# 1  90028       NaN                 NaN        NOT EMPLOYED       $10.00
# 2  10010       NaN     BLOOMER BIOTECH  INVESTMENT ADVISOR      $100.00
# 3  94904       NaN  COOPER & MCCLOSKEY    INSURANCE BROKER      $150.00
# 4  94020       NaN                 NaN        NOT EMPLOYED       $25.00
#
#   TRANSACTION DATE FILED DATE  TRANSACTION NUMBER
# 0       2021-09-07 2022-05-20   2625145 - EXP2027
# 1       2021-07-01 2022-05-20  2625145 - IDT41416
# 2       2021-07-01 2022-05-20  2625145 - IDT41417
# 3       2021-07-01 2022-05-20  2625145 - IDT41424
# 4       2021-07-01 2022-05-20  2625145 - IDT41425

# %%
# replace commas with nothing
data['AMOUNT'] = data['AMOUNT'].str.replace(',', '')

# replace dollar sign with nothing
data['AMOUNT'] = data['AMOUNT'].str.replace('$', '')
# Out:
# /var/folders/9b/jnjvzdvx77z055tn96mc36980000gp/T/ipykernel_26112/1289595486.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['AMOUNT'] = data['AMOUNT'].str.replace('$', '')

# %%
data
# Out:
#                            NAME OF CONTRIBUTOR PAYMENT TYPE           CITY  \
# 0      CALIFORNIA CHIROPRACTIC ASSOCIATION PAC     MONETARY     SACRAMENTO
# 1                               MARINA BILAVER     MONETARY      HOLLYWOOD
# 2                              CAMERON BLOOMER     MONETARY       NEW YORK
# 3                              ALISON FLEMMING     MONETARY       LARKSPUR
# 4                               WILLIAM FOWKES     MONETARY       LA HONDA
# ...                                        ...          ...            ...
# 23381                     1-800 CONTACTS, INC.     MONETARY         DRAPER
# 23382                       T-MOBILE USA, INC.     MONETARY       BELLEVUE
# 23383      GOOGLE, LLC AND AFFILIATED ENTITIES     MONETARY  MOUNTAIN VIEW
# 23384                     AIRLINES FOR AMERICA     MONETARY     WASHINGTON
# 23385                          JOSEPH E. GORST     MONETARY      SAN DIEGO
#
#       STATE    ZIP ID NUMBER            EMPLOYER          OCCUPATION  \
# 0        CA  95814    742986                 NaN                 NaN
# 1        CA  90028       NaN                 NaN        NOT EMPLOYED
# 2        NY  10010       NaN     BLOOMER BIOTECH  INVESTMENT ADVISOR
# 3        CA  94904       NaN  COOPER & MCCLOSKEY    INSURANCE BROKER
# 4        CA  94020       NaN                 NaN        NOT EMPLOYED
# ...     ...    ...       ...                 ...                 ...
# 23381    UT  84020       NaN                 NaN                 NaN
# 23382    WA  98006       NaN                 NaN                 NaN
# 23383    CA  94043       NaN                 NaN                 NaN
# 23384    DC  20004       NaN                 NaN                 NaN
# 23385    CA  92103       NaN                 NaN             RETIRED
#
#            AMOUNT TRANSACTION DATE FILED DATE  TRANSACTION NUMBER
# 0      (15000.00)       2021-09-07 2022-05-20   2625145 - EXP2027
# 1          10.00        2021-07-01 2022-05-20  2625145 - IDT41416
# 2         100.00        2021-07-01 2022-05-20  2625145 - IDT41417
# 3         150.00        2021-07-01 2022-05-20  2625145 - IDT41424
# 4          25.00        2021-07-01 2022-05-20  2625145 - IDT41425
# ...           ...              ...        ...                 ...
# 23381   10000.00        2021-12-22 2022-06-06   2644331 - INC3631
# 23382    5000.00        2021-12-22 2022-06-06   2644331 - INC3632
# 23383   32400.00        2021-12-27 2022-06-06   2644331 - INC3634
# 23384   10000.00        2021-12-28 2022-06-06   2644331 - INC3642
# 23385     500.00        2021-12-31 2022-06-06   2644331 - INC3650
#
# [23386 rows x 12 columns]

# %%
# replace right parenthesis with nothing
data['AMOUNT'] = data['AMOUNT'].str.replace(')', '')

# replace left parenthesis with negative!
data['AMOUNT'] = data['AMOUNT'].str.replace('(', '-')
# Out:
# /var/folders/9b/jnjvzdvx77z055tn96mc36980000gp/T/ipykernel_26112/1668344156.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['AMOUNT'] = data['AMOUNT'].str.replace(')', '')
# /var/folders/9b/jnjvzdvx77z055tn96mc36980000gp/T/ipykernel_26112/1668344156.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['AMOUNT'] = data['AMOUNT'].str.replace('(', '-')

# %%
data
# Out:
#                            NAME OF CONTRIBUTOR PAYMENT TYPE           CITY  \
# 0      CALIFORNIA CHIROPRACTIC ASSOCIATION PAC     MONETARY     SACRAMENTO
# 1                               MARINA BILAVER     MONETARY      HOLLYWOOD
# 2                              CAMERON BLOOMER     MONETARY       NEW YORK
# 3                              ALISON FLEMMING     MONETARY       LARKSPUR
# 4                               WILLIAM FOWKES     MONETARY       LA HONDA
# ...                                        ...          ...            ...
# 23381                     1-800 CONTACTS, INC.     MONETARY         DRAPER
# 23382                       T-MOBILE USA, INC.     MONETARY       BELLEVUE
# 23383      GOOGLE, LLC AND AFFILIATED ENTITIES     MONETARY  MOUNTAIN VIEW
# 23384                     AIRLINES FOR AMERICA     MONETARY     WASHINGTON
# 23385                          JOSEPH E. GORST     MONETARY      SAN DIEGO
#
#       STATE    ZIP ID NUMBER            EMPLOYER          OCCUPATION  \
# 0        CA  95814    742986                 NaN                 NaN
# 1        CA  90028       NaN                 NaN        NOT EMPLOYED
# 2        NY  10010       NaN     BLOOMER BIOTECH  INVESTMENT ADVISOR
# 3        CA  94904       NaN  COOPER & MCCLOSKEY    INSURANCE BROKER
# 4        CA  94020       NaN                 NaN        NOT EMPLOYED
# ...     ...    ...       ...                 ...                 ...
# 23381    UT  84020       NaN                 NaN                 NaN
# 23382    WA  98006       NaN                 NaN                 NaN
# 23383    CA  94043       NaN                 NaN                 NaN
# 23384    DC  20004       NaN                 NaN                 NaN
# 23385    CA  92103       NaN                 NaN             RETIRED
#
#           AMOUNT TRANSACTION DATE FILED DATE  TRANSACTION NUMBER
# 0      -15000.00       2021-09-07 2022-05-20   2625145 - EXP2027
# 1         10.00        2021-07-01 2022-05-20  2625145 - IDT41416
# 2        100.00        2021-07-01 2022-05-20  2625145 - IDT41417
# 3        150.00        2021-07-01 2022-05-20  2625145 - IDT41424
# 4         25.00        2021-07-01 2022-05-20  2625145 - IDT41425
# ...          ...              ...        ...                 ...
# 23381  10000.00        2021-12-22 2022-06-06   2644331 - INC3631
# 23382   5000.00        2021-12-22 2022-06-06   2644331 - INC3632
# 23383  32400.00        2021-12-27 2022-06-06   2644331 - INC3634
# 23384  10000.00        2021-12-28 2022-06-06   2644331 - INC3642
# 23385    500.00        2021-12-31 2022-06-06   2644331 - INC3650
#
# [23386 rows x 12 columns]

# %% [markdown]
# ## String cleaning
#
# But first, let's talk about regex, or regular expressions.
#
# We'll go through some of the lessons here: https://regexone.com/

# %% [markdown]
# ## String normalizing
#
# The following code replaces 2+ whitespaces with 1 whitespace:
#
# ```python
# df['column_name'] = df['column_name'].str.replace(r'[ ]+', ' ', regex=True)
# ```
#
# Remove leading and trailing whitespaces:
#
# ```python
# df['column_name'] = df['column_name'].str.strip()
# ```
#
# Uppercase a column (you don't have to do for this particular dataset):
#
# ```python
# df['column_name'] = df['column_name'].str.upper()
# ```

# %% [markdown]
# POLL: If I'm trying to get the count and amount of corporate contributions to Newsom, how would I do this?
# [https://pollev.com/soooh](https://pollev.com/soooh)
